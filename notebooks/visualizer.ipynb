# %%
import pandas as pd
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.visualizer import plot_price_with_moving_averages, plot_rsi, plot_macd

stocks = ['apple', 'amazon', 'meta', 'microsoft', 'nvidia', 'tesla', 'google']

for stock in stocks:
    path = f'../data/cleaned_data/indicators/{stock}_indicators.csv'
    df = pd.read_csv(path)
    df['Date'] = pd.to_datetime(df['Date'])

    print(f"\n Visualizing: {stock.upper()}")
    plot_price_with_moving_averages(df, stock.title())
    plot_rsi(df, stock.title())
    plot_macd(df, stock.title())
# Out:
#  Visualizing: APPLE
#  Visualizing: AMAZON
#  Visualizing: META
#  Visualizing: MICROSOFT
#  Visualizing: NVIDIA
#  Visualizing: TESLA
#  Visualizing: GOOGLE
